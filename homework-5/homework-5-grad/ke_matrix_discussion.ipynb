# %%
import ke_matrix as ke
import matplotlib.pyplot as plt

# %% [markdown]
# ### Note
#
# I tried doing the plotting within this file, but it kept giving me errors when I tried accessing the variables in the ke_matrix.py file. As a result, I added the plotting within the .py file.

# %% [markdown]
# ## Diagonal Kinetic Energy Matrix Element (Kii) Using Random Sampling
#
# The Kii converges to 0.5 after 10^8 points have been sampled.

# %% [markdown]
# ## Diagonal Kinetic Energy Matrix Element (Kii) Using Importance Sampling
#
# The Kii converges to 0.5 after 10^6 points have been sampled, which is two orders of magnitude more efficient than random sampling.

# %% [markdown]
# ## Off-diagonal Kinetic Energy Matrix Element (Kij) Using Random Sampling
#
# The Kij doesn't have a clear convergence. Nonetheless, it reaches 0.21 after 10^8 points have been sampled.

# %% [markdown]
# ## Off-diagonal Kinetic Energy Matrix Element (Kij) Using Importance Sampling
#
# The Kij converges to 0.21 after 10^5 points have been sampled, which is three orders of magnitude more efficient than random sampling.
